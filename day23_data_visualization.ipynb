# %% [markdown]
# <b>Common Graphs</b>
# * Line Plot
# * Histogram
# * Bar Graph
# * Scatter
# * Boxplot
# * stem
# * violinplot
# * kernel density estimator

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
plt.plot(tips['total_bill'])

# %%
tips['total_bill'].plot()

# %%
plt.figure(figsize=(20,8))
_ = plt.plot(tips['total_bill'],color='r',lw=2,ls='-',marker='*',markersize=15,markerfacecolor='yellow',markeredgecolor='blue')
_ = plt.title('Total Bill Line Plot')
_ = plt.grid()
_ = plt.xlabel('Entries-->')
_ = plt.ylabel('Bill Amount (in $)-->')
_ = plt.xticks(range(0,245,5))

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
_ = plt.plot(tips['total_bill'],color='r',lw=2,ls='-',marker='*',markersize=15,markerfacecolor='yellow',markeredgecolor='blue')
_ = plt.title('Total Bill Line Plot')
_ = plt.grid()
_ = plt.xlabel('Entries-->')
_ = plt.ylabel('Bill Amount (in $)-->')
_ = plt.xticks(range(0,245,5))

plt.subplot(1,2,2)
_ = plt.plot(tips['tip'],color='g',lw=2,ls='-',marker='*',markersize=15,markerfacecolor='yellow',markeredgecolor='blue')
_ = plt.title('Total Tip Line Plot')
_ = plt.grid()
_ = plt.xlabel('Entries-->')
_ = plt.ylabel('Tip Amount (in $)-->')
_ = plt.xticks(range(0,245,5))

# %%
tips['total_bill'].plot(figsize=(20,8),grid=True,xlabel='Entries')

# %%
_ = plt.hist(tips['total_bill'],bins=30)

# %%
# _ = plt.bar(tips['tip'],tips['total_bill'])

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
_ = plt.boxplot(tips['total_bill'])

# %%
_ = plt.scatter(tips['total_bill'],tips['tip'])
plt.xlabel('total bill')
plt.ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
_=plt.violinplot(tips['total_bill'])

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
plt.pie(tips['sex'].value_counts(),autopct='%d',labels=['male','female'])
# Out:
# ([<matplotlib.patches.Wedge at 0x24815df6f40>,
# ...
#  [Text(-0.47909423581850497, 0.9901862012800839, 'male'),
#   Text(0.4790942358185044, -0.9901862012800842, 'female')],
#  [Text(-0.2613241286282754, 0.5401015643345912, '64'),
#   Text(0.2613241286282751, -0.5401015643345913, '35')])

# %% [markdown]
# # Seaborn

# %% [raw]
# 1. Categorical
#     - at least one categorical column would be there
#         * countplot
#         * boxplot
#         * barplot
#         * violinplot
#         * swarmplot
#         * stripplot
# 2. Distribution
#     - at least one cont. numerical data
#         * displot
#         * histplot
#         * kdeplot
#         * rugplot
#         * lineplot
#         * jointplot#
# 3. Matrix
#     - categorical (numerical) or cont. numerical
#         * pairplot
#         * heatmap
#         * clustermap
# 4. Grids
#     - one categorical, one cont numerical
#         * PairGrid
#         * JointGrid
#         * FacetGrid
# 5. Regression
#     - two cont numerical
#         * regplot
#         * scatterplot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.countplot(x='sex',data=tips,hue='smoker')

# %%
sns.countplot(x='day',data=tips,)

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x='day',y='total_bill',data=tips,)

# %%
sns.barplot(x='day',y='total_bill',data=tips)

# %%
sns.barplot(x='day',y='total_bill',data=tips,estimator=sum)

# %%
sns.barplot(x='day',y='total_bill',data=tips,hue='sex')

# %%
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)

# %%
sns.stripplot(x='day',y='total_bill',data=tips)

# %%
sns.displot(data=tips,x='tip')

# %%
sns.distplot(tips['tip'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(data=tips,x='tip')

# %%
sns.histplot(data=tips,x='tip')

# %%
sns.rugplot(data=tips,x='tip')

# %%
sns.displot(data=tips,x='tip',color='r')
sns.rugplot(data=tips,x='tip',color='y')

# %%
sns.lineplot(x=range(244), y ='total_bill', data=tips,hue='smoker')

# %%
sns.jointplot(x='tip',y='total_bill',data=tips)

# %%
sns.regplot(x='tip',y='total_bill',data=tips)

# %%
sns.lmplot(x='tip',y='total_bill',data=tips)

# %%
sns.pairplot(tips)

# %%
sns.heatmap(tips.corr(),annot=True)

# %%
flight = sns.load_dataset('flights')

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = flight.pivot_table(values='passengers',index='year',columns='month')

# %%
flights
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(flights,cmap='magma')

# %%
sns.clustermap(flights)
